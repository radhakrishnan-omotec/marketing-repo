# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/marketing-repo/blob/main/1_Project_Impact_of_AI_Tools_in_Marketing_Industry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Impact of AI Tools in Marketing Industry

# %% [markdown]
# Assess the impact of artificial intelligence (AI) tools on the roles, skills, and job functions within the marketing industry

# %% [markdown]
# The study aims to provide a thorough understanding of the transformative effect of AI in marketing, offering insights into current adaptations and forecasting future industry shifts.
#
# The primary objective of this research is to comprehensively assess the impact of artificial intelligence (AI) tools on the roles, skills, and job functions within the marketing industry. This involves examining how the integration of AI is reshaping the landscape of marketing jobs, from altering traditional roles and responsibilities to necessitating new skill sets and competencies among professionals.
#
# The secondary objectives focus on understanding how marketing professionals are adapting to the integration of AI in their workflows. This includes exploring their responses to the evolving technological landscape, the strategies they employ to integrate AI tools into their daily tasks, and identifying emerging trends and potential future implications of AI in the marketing domain.

# %% [markdown]
# ### IMPLEMENTATION STEPS::
#
# Using the AI tools what is the impact of Marketing tools , how easy task has become or how hard. What is the impact in marketing
#
# Google form creation for Marketing 50 - 60 dataset ( Target 100 )
# Using the AI tools what is the impact of Marketing tools How easy task has become or how hard. What is the impact in marketing.

# %%
# !git clone https://github.com/radhakrishnan-omotec/marketing-repo.git
# Out:
# Cloning into 'marketing-repo'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 2.29 MiB | 11.91 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import pandas as pd

# %%
input_df = pd.read_csv("/content/marketing-repo/CSV Impact of AI Tools in Marketing Industry.csv")
input_df.head()
# Out:
#    S.No Name of the Participant Designation / Title Age Group  \
# 0     1                 Rajan R            Employee     21-30
# 1     2          Jahsey Onfroy               Intern    18 -20
# 2     3            Vipul Jasani   Business Director       >50
# 3     4       Unnikrishnan Nair            Employee       >50
# 4     5           Rajesh Manke              Manager       >50
#
#   Is AI being used in the marketing department of your company?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   1. How has the use of AI tools impacted your current marketing role?  \
# 0  (a) My responsibilities have shifted towards m...
# 1  (a) My responsibilities have shifted towards m...
# 2  (a) My responsibilities have shifted towards m...
# 3  (d) No significant impact, my tasks remain pri...
# 4  (a) My responsibilities have shifted towards m...
#
#   2. Which of the following skills has become more important due to AI integration in marketing?  \
# 0      (b) Creative content writing and storytelling
# 1   (d) Project management and organizational skills
# 2               (a) Data analysis and interpretation
# 3   (d) Project management and organizational skills
# 4               (a) Data analysis and interpretation
#
#   3. How comfortable are you with the idea of AI eventually performing tasks currently considered core to your marketing expertise?  \
# 0  (c) Neutral, I accept the inevitability of cha...
# 1  (b) Somewhat comfortable, as long as AI remain...
# 2  (a) Very comfortable, as it allows me to focus...
# 3  (a) Very comfortable, as it allows me to focus...
# 4  (b) Somewhat comfortable, as long as AI remain...
#
#   4. To effectively utilize AI tools in marketing, how important is collaboration between humans and AI?  \
# 0  (d) Not necessary, AI can efficiently manage t...
# 1  (b) Important, but AI can often handle tasks a...
# 2  (a) Essential, human oversight and guidance ar...
# 3  (c) Somewhat beneficial, but AI can generally ...
# 4  (b) Important, but AI can often handle tasks a...
#
#   5. Which aspect of your marketing workflow has been most impacted by AI tools?  \
# 0         (a) Social media management and engagement
# 1        (c) Email marketing and campaign automation
# 2        (c) Email marketing and campaign automation
# 3          (d) Market research and customer analysis
# 4        (c) Email marketing and campaign automation
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   9. How has the use of AI tools affected your work-life balance as a marketing professional?  \
# 0  (a) Reduced workload and stress, enabling bett...
# 1  (a) Reduced workload and stress, enabling bett...
# 2  (d) No significant impact, my work schedule re...
# 3  (a) Reduced workload and stress, enabling bett...
# 4  (a) Reduced workload and stress, enabling bett...
#
#   11. In your experience, how transparent have your organizations been about the implementation of AI tools in marketing?  \
# 0  (c) Not very transparent, leaving employees fe...
# 1  (b) Somewhat transparent, but some concerns ar...
# 2  (a) Very transparent, with clear communication...
# 3  (a) Very transparent, with clear communication...
# 4  (a) Very transparent, with clear communication...
#
#   12. Which ethical concern regarding AI use in marketing do you find most pressing?  \
# 0  (d) Environmental impact of data centers and e...
# 1  (b) Lack of human control over AI decisions wi...
# 2  (c) Manipulation of user behavior and erosion ...
# 3  (d) Environmental impact of data centers and e...
# 4  (c) Manipulation of user behavior and erosion ...
#
#   13. How willing are you to participate in further training and development to keep up with advancements in AI-powered marketing?  \
# 0  (a) Very willing, continuous learning is essen...
# 1  (a) Very willing, continuous learning is essen...
# 2  (a) Very willing, continuous learning is essen...
# 3  (a) Very willing, continuous learning is essen...
# 4  (a) Very willing, continuous learning is essen...
#
#   14. Which statement best describes your overall sentiment towards the integration of AI in the marketing industry?  \
# 0  (c) Neutral, accepting the change while observ...
# 1  (b) Cautiously optimistic, but with concerns a...
# 2  (b) Cautiously optimistic, but with concerns a...
# 3  (a) Excited and optimistic about the potential...
# 4  (a) Excited and optimistic about the potential...
#
#   15. In your opinion, what is the single most important factor for ensuring a successful human-AI collaboration in the future of marketing?  \
# 0  (a) Building trust and transparency in AI algo...
# 1  (a) Building trust and transparency in AI algo...
# 2  (c) Establishing clear roles and responsibilit...
# 3  (d) Fostering a culture of innovation and embr...
# 4  (b) Continuously upskilling and reskilling mar...
#
#   16. Which AI-powered social media management tool are you most familiar with?  \
# 0                                  (b) Sprout Social
# 1                                         (c) Buffer
# 2                                  (b) Sprout Social
# 3                                         (c) Buffer
# 4                                  (b) Sprout Social
#
#   17. Which AI-based marketing automation tool would you find most helpful in your work?  \
# 0  (c) Chatbot and virtual assistant tools (e.g.,...
# 1  (a) Email marketing automation (e.g., Mailchim...
# 2  (a) Email marketing automation (e.g., Mailchim...
# 3  (a) Email marketing automation (e.g., Mailchim...
# 4  (a) Email marketing automation (e.g., Mailchim...
#
#   18.  How has the introduction of AI tools affected your workload in the marketing department?  \
# 0                              D) Slightly decreased
# 1                         E) Significantly decreased
# 2                            C) No noticeable change
# 3                              B) Slightly increased
# 4                         E) Significantly decreased
#
#   19.  How has the integration of AI tools affected your daily tasks in the marketing department?
# 0                  B) Minimally impacted daily tasks
# 1  A) Streamlined processes and increased efficiency
# 2                  B) Minimally impacted daily tasks
# 3                  B) Minimally impacted daily tasks
# 4                  B) Minimally impacted daily tasks
#
# [5 rows x 23 columns]

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 23 columns):
#  #   Column                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                      --------------  -----
#  0   S.No                                                                                                                                        90 non-null     int64
#  1   Name of the Participant                                                                                                                     90 non-null     object
#  2   Designation / Title                                                                                                                         90 non-null     object
#  3   Age Group                                                                                                                                   90 non-null     object
#  4   Is AI being used in the marketing department of your company?                                                                               90 non-null     object
#  5   1. How has the use of AI tools impacted your current marketing role?                                                                        90 non-null     object
#  6   2. Which of the following skills has become more important due to AI integration in marketing?                                              90 non-null     object
#  7   3. How comfortable are you with the idea of AI eventually performing tasks currently considered core to your marketing expertise?           90 non-null     object
#  8   4. To effectively utilize AI tools in marketing, how important is collaboration between humans and AI?                                      90 non-null     object
#  9   5. Which aspect of your marketing workflow has been most impacted by AI tools?                                                              90 non-null     object
#  10  6. How confident are you in your ability to adapt to future changes in marketing due to AI advancements?                                    90 non-null     object
#  11  7. In your opinion, what is the biggest challenge marketing professionals face when integrating AI tools?                                   90 non-null     object
#  12  8. Which statement best describes your perception of the future of marketing jobs with AI?                                                  90 non-null     object
#  13  9. How has the use of AI tools affected your work-life balance as a marketing professional?                                                 90 non-null     object
#  14  11. In your experience, how transparent have your organizations been about the implementation of AI tools in marketing?                     90 non-null     object
#  15  12. Which ethical concern regarding AI use in marketing do you find most pressing?                                                          90 non-null     object
#  16  13. How willing are you to participate in further training and development to keep up with advancements in AI-powered marketing?            90 non-null     object
#  17  14. Which statement best describes your overall sentiment towards the integration of AI in the marketing industry?                          90 non-null     object
#  18  15. In your opinion, what is the single most important factor for ensuring a successful human-AI collaboration in the future of marketing?  90 non-null     object
#  19  16. Which AI-powered social media management tool are you most familiar with?                                                               90 non-null     object
#  20  17. Which AI-based marketing automation tool would you find most helpful in your work?                                                      90 non-null     object
#  21  18.  How has the introduction of AI tools affected your workload in the marketing department?                                               90 non-null     object
#  22  19.  How has the integration of AI tools affected your daily tasks in the marketing department?                                             90 non-null     object
# dtypes: int64(1), object(22)
# memory usage: 16.3+ KB

# %%
input_df.describe()
# Out:
#             S.No
# count  90.000000
# mean   45.500000
# std    26.124701
# min     1.000000
# 25%    23.250000
# 50%    45.500000
# 75%    67.750000
# max    90.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['S.No'].plot(kind='hist', bins=20, title='S.No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['S.No'].plot(kind='line', figsize=(8, 4), title='S.No')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
input_df
# Out:
#     S.No Name of the Participant Designation / Title Age Group  \
# 0      1                 Rajan R            Employee     21-30
# 1      2          Jahsey Onfroy               Intern    18 -20
# 2      3            Vipul Jasani   Business Director       >50
# 3      4       Unnikrishnan Nair            Employee       >50
# 4      5           Rajesh Manke              Manager       >50
# ..   ...                     ...                 ...       ...
# 85    86          Shivesh Kapoor             Manager     40-50
# 86    87          Yash Ghualewal            Employee     21-30
# 87    88           Kamini Sanghi             Manager     30-40
# 88    89             Azhar khan             Employee     21-30
# 89    90     Radhakrishnan Rajan            Employee     30-40
#
#    Is AI being used in the marketing department of your company?  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# 85                                                Yes
# 86                                                Yes
# 87                                                Yes
# 88                                                 No
# 89                                                Yes
#
#    1. How has the use of AI tools impacted your current marketing role?  \
# 0   (a) My responsibilities have shifted towards m...
# 1   (a) My responsibilities have shifted towards m...
# 2   (a) My responsibilities have shifted towards m...
# 3   (d) No significant impact, my tasks remain pri...
# 4   (a) My responsibilities have shifted towards m...
# ..                                                ...
# 85  (a) My responsibilities have shifted towards m...
# 86  (a) My responsibilities have shifted towards m...
# 87  (a) My responsibilities have shifted towards m...
# 88  (a) My responsibilities have shifted towards m...
# 89  (a) My responsibilities have shifted towards m...
#
#    2. Which of the following skills has become more important due to AI integration in marketing?  \
# 0       (b) Creative content writing and storytelling
# 1    (d) Project management and organizational skills
# 2                (a) Data analysis and interpretation
# 3    (d) Project management and organizational skills
# 4                (a) Data analysis and interpretation
# ..                                                ...
# 85               (c) Coding and programming knowledge
# 86               (c) Coding and programming knowledge
# 87               (a) Data analysis and interpretation
# 88               (a) Data analysis and interpretation
# 89               (c) Coding and programming knowledge
#
#    3. How comfortable are you with the idea of AI eventually performing tasks currently considered core to your marketing expertise?  \
# 0   (c) Neutral, I accept the inevitability of cha...
# 1   (b) Somewhat comfortable, as long as AI remain...
# 2   (a) Very comfortable, as it allows me to focus...
# 3   (a) Very comfortable, as it allows me to focus...
# 4   (b) Somewhat comfortable, as long as AI remain...
# ..                                                ...
# 85  (b) Somewhat comfortable, as long as AI remain...
# 86  (b) Somewhat comfortable, as long as AI remain...
# 87  (b) Somewhat comfortable, as long as AI remain...
# 88  (a) Very comfortable, as it allows me to focus...
# 89  (a) Very comfortable, as it allows me to focus...
#
#    4. To effectively utilize AI tools in marketing, how important is collaboration between humans and AI?  \
# 0   (d) Not necessary, AI can efficiently manage t...
# 1   (b) Important, but AI can often handle tasks a...
# 2   (a) Essential, human oversight and guidance ar...
# 3   (c) Somewhat beneficial, but AI can generally ...
# 4   (b) Important, but AI can often handle tasks a...
# ..                                                ...
# 85  (a) Essential, human oversight and guidance ar...
# 86  (b) Important, but AI can often handle tasks a...
# 87  (b) Important, but AI can often handle tasks a...
# 88  (a) Essential, human oversight and guidance ar...
# 89  (a) Essential, human oversight and guidance ar...
#
#    5. Which aspect of your marketing workflow has been most impacted by AI tools?  \
# 0          (a) Social media management and engagement
# 1         (c) Email marketing and campaign automation
# 2         (c) Email marketing and campaign automation
# 3           (d) Market research and customer analysis
# 4         (c) Email marketing and campaign automation
# ..                                                ...
# 85  (b) Search engine optimization (SEO) and conte...
# 86         (a) Social media management and engagement
# 87  (b) Search engine optimization (SEO) and conte...
# 88         (a) Social media management and engagement
# 89          (d) Market research and customer analysis
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 85  ...
# 86  ...
# 87  ...
# 88  ...
# 89  ...
#
#    9. How has the use of AI tools affected your work-life balance as a marketing professional?  \
# 0   (a) Reduced workload and stress, enabling bett...
# 1   (a) Reduced workload and stress, enabling bett...
# 2   (d) No significant impact, my work schedule re...
# 3   (a) Reduced workload and stress, enabling bett...
# 4   (a) Reduced workload and stress, enabling bett...
# ..                                                ...
# 85  (a) Reduced workload and stress, enabling bett...
# 86  (a) Reduced workload and stress, enabling bett...
# 87  (a) Reduced workload and stress, enabling bett...
# 88  (a) Reduced workload and stress, enabling bett...
# 89  (a) Reduced workload and stress, enabling bett...
#
#    11. In your experience, how transparent have your organizations been about the implementation of AI tools in marketing?  \
# 0   (c) Not very transparent, leaving employees fe...
# 1   (b) Somewhat transparent, but some concerns ar...
# 2   (a) Very transparent, with clear communication...
# 3   (a) Very transparent, with clear communication...
# 4   (a) Very transparent, with clear communication...
# ..                                                ...
# 85  (b) Somewhat transparent, but some concerns ar...
# 86  (b) Somewhat transparent, but some concerns ar...
# 87  (b) Somewhat transparent, but some concerns ar...
# 88  (a) Very transparent, with clear communication...
# 89  (a) Very transparent, with clear communication...
#
#    12. Which ethical concern regarding AI use in marketing do you find most pressing?  \
# 0   (d) Environmental impact of data centers and e...
# 1   (b) Lack of human control over AI decisions wi...
# 2   (c) Manipulation of user behavior and erosion ...
# 3   (d) Environmental impact of data centers and e...
# 4   (c) Manipulation of user behavior and erosion ...
# ..                                                ...
# 85  (b) Lack of human control over AI decisions wi...
# 86  (b) Lack of human control over AI decisions wi...
# 87  (b) Lack of human control over AI decisions wi...
# 88  (a) Bias and discrimination in algorithms lead...
# 89  (d) Environmental impact of data centers and e...
#
#    13. How willing are you to participate in further training and development to keep up with advancements in AI-powered marketing?  \
# 0   (a) Very willing, continuous learning is essen...
# 1   (a) Very willing, continuous learning is essen...
# 2   (a) Very willing, continuous learning is essen...
# 3   (a) Very willing, continuous learning is essen...
# 4   (a) Very willing, continuous learning is essen...
# ..                                                ...
# 85  (b) Somewhat willing, depending on the relevan...
# 86  (b) Somewhat willing, depending on the relevan...
# 87  (b) Somewhat willing, depending on the relevan...
# 88  (a) Very willing, continuous learning is essen...
# 89  (b) Somewhat willing, depending on the relevan...
#
#    14. Which statement best describes your overall sentiment towards the integration of AI in the marketing industry?  \
# 0   (c) Neutral, accepting the change while observ...
# 1   (b) Cautiously optimistic, but with concerns a...
# 2   (b) Cautiously optimistic, but with concerns a...
# 3   (a) Excited and optimistic about the potential...
# 4   (a) Excited and optimistic about the potential...
# ..                                                ...
# 85  (b) Cautiously optimistic, but with concerns a...
# 86  (b) Cautiously optimistic, but with concerns a...
# 87  (b) Cautiously optimistic, but with concerns a...
# 88  (a) Excited and optimistic about the potential...
# 89  (a) Excited and optimistic about the potential...
#
#    15. In your opinion, what is the single most important factor for ensuring a successful human-AI collaboration in the future of marketing?  \
# 0   (a) Building trust and transparency in AI algo...
# 1   (a) Building trust and transparency in AI algo...
# 2   (c) Establishing clear roles and responsibilit...
# 3   (d) Fostering a culture of innovation and embr...
# 4   (b) Continuously upskilling and reskilling mar...
# ..                                                ...
# 85  (a) Building trust and transparency in AI algo...
# 86  (a) Building trust and transparency in AI algo...
# 87  (a) Building trust and transparency in AI algo...
# 88  (a) Building trust and transparency in AI algo...
# 89  (b) Continuously upskilling and reskilling mar...
#
#    16. Which AI-powered social media management tool are you most familiar with?  \
# 0                                   (b) Sprout Social
# 1                                          (c) Buffer
# 2                                   (b) Sprout Social
# 3                                          (c) Buffer
# 4                                   (b) Sprout Social
# ..                                                ...
# 85                              (e) None of the above
# 86                              (e) None of the above
# 87                              (e) None of the above
# 88                              (e) None of the above
# 89                                      (d) Meltwater
#
#    17. Which AI-based marketing automation tool would you find most helpful in your work?  \
# 0   (c) Chatbot and virtual assistant tools (e.g.,...
# 1   (a) Email marketing automation (e.g., Mailchim...
# 2   (a) Email marketing automation (e.g., Mailchim...
# 3   (a) Email marketing automation (e.g., Mailchim...
# 4   (a) Email marketing automation (e.g., Mailchim...
# ..                                                ...
# 85  (d) Content personalization and optimization t...
# 86  (d) Content personalization and optimization t...
# 87  (a) Email marketing automation (e.g., Mailchim...
# 88  (a) Email marketing automation (e.g., Mailchim...
# 89  (b) Paid advertising automation (e.g., Google ...
#
#    18.  How has the introduction of AI tools affected your workload in the marketing department?  \
# 0                               D) Slightly decreased
# 1                          E) Significantly decreased
# 2                             C) No noticeable change
# 3                               B) Slightly increased
# 4                          E) Significantly decreased
# ..                                                ...
# 85                            C) No noticeable change
# 86                              B) Slightly increased
# 87                              B) Slightly increased
# 88                         A) Significantly increased
# 89                              B) Slightly increased
#
#    19.  How has the integration of AI tools affected your daily tasks in the marketing department?
# 0                   B) Minimally impacted daily tasks
# 1   A) Streamlined processes and increased efficiency
# 2                   B) Minimally impacted daily tasks
# 3                   B) Minimally impacted daily tasks
# 4                   B) Minimally impacted daily tasks
# ..                                                ...
# 85  A) Streamlined processes and increased efficiency
# 86  A) Streamlined processes and increased efficiency
# 87  A) Streamlined processes and increased efficiency
# 88  A) Streamlined processes and increased efficiency
# 89  A) Streamlined processes and increased efficiency
#
# [90 rows x 23 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# input_df['S.No'].plot(kind='hist', bins=20, title='S.No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# input_df.groupby('Age Group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# input_df.groupby('Is AI being used in the marketing department of your company?').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# input_df.groupby('1. How has the use of AI tools impacted your current marketing role?').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# input_df.groupby('2. Which of the following skills has become more important due to AI integration in marketing?').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = input_df.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Age Group')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Age Group', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = input_df.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Is AI being used in the marketing department of your company?')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Is AI being used in the marketing department of your company?', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = input_df.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('1. How has the use of AI tools impacted your current marketing role?')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='1. How has the use of AI tools impacted your current marketing role?', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['S.No']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'S.No'}, axis=1)
#               .sort_values('S.No', ascending=True))
#   xs = counted['S.No']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = input_df.sort_values('S.No', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('2. Which of the following skills has become more important due to AI integration in marketing?')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='2. Which of the following skills has become more important due to AI integration in marketing?', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('S.No')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# input_df['S.No'].plot(kind='line', figsize=(8, 4), title='S.No')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Is AI being used in the marketing department of your company?'].value_counts()
#     for x_label, grp in input_df.groupby('Age Group')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Age Group')
# _ = plt.ylabel('Is AI being used in the marketing department of your company?')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['1. How has the use of AI tools impacted your current marketing role?'].value_counts()
#     for x_label, grp in input_df.groupby('Is AI being used in the marketing department of your company?')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Is AI being used in the marketing department of your company?')
# _ = plt.ylabel('1. How has the use of AI tools impacted your current marketing role?')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['2. Which of the following skills has become more important due to AI integration in marketing?'].value_counts()
#     for x_label, grp in input_df.groupby('1. How has the use of AI tools impacted your current marketing role?')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('1. How has the use of AI tools impacted your current marketing role?')
# _ = plt.ylabel('2. Which of the following skills has become more important due to AI integration in marketing?')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['3. How comfortable are you with the idea of AI eventually performing tasks currently considered core to your marketing expertise?'].value_counts()
#     for x_label, grp in input_df.groupby('2. Which of the following skills has become more important due to AI integration in marketing?')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('2. Which of the following skills has become more important due to AI integration in marketing?')
# _ = plt.ylabel('3. How comfortable are you with the idea of AI eventually performing tasks currently considered core to your marketing expertise?')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(input_df['Age Group'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(input_df, x='S.No', y='Age Group', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(input_df['Is AI being used in the marketing department of your company?'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(input_df, x='S.No', y='Is AI being used in the marketing department of your company?', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(input_df['1. How has the use of AI tools impacted your current marketing role?'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(input_df, x='S.No', y='1. How has the use of AI tools impacted your current marketing role?', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(input_df['2. Which of the following skills has become more important due to AI integration in marketing?'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(input_df, x='S.No', y='2. Which of the following skills has become more important due to AI integration in marketing?', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
